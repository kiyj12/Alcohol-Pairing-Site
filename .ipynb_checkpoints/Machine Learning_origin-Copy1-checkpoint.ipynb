# %% [markdown]
# # Data loading

# %%
import numpy as np
import pandas as pd

import os
print(os.listdir('./data/'))
# Out:
# ['beer_pairing (ENG).xlsx', 'recipes_82k.csv', 'test.json', 'test.json.zip', 'train.json', 'train.json.zip', 'Wine_pairing.xlsx']

# %%
df = pd.concat([pd.read_json('./data/train/train.json'), 
                pd.read_json('./data/test/test.json')]).reset_index()

# Lower-casing all ingredients' name.
df['ingredients'] = df['ingredients'].apply(lambda ings : [ing.lower() for ing in ings])

df.head()
# Out:
#    index     id      cuisine  \
# 0      0  10259        greek
# 1      1  25693  southern_us
# 2      2  20130     filipino
# 3      3  22213       indian
# 4      4  13162       indian
#
#                                          ingredients
# 0  [romaine lettuce, black olives, grape tomatoes...
# 1  [plain flour, ground pepper, salt, tomatoes, g...
# 2  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3                [water, vegetable oil, wheat, salt]
# 4  [black pepper, shallots, cornflour, cayenne pe...

# %% [markdown]
# # Calculating ingredient co-occurrences.
#
# Simply calculating the number of recipes in which two ingredients occurred together.
#
# Using itertools
#
# <strong>permutations</strong> : 순열 구하기
#
# <strong>combinations</strong> : 조합 구하기

# %%
import itertools

# Test
list(itertools.combinations(df['ingredients'][0][:6], 2))
# Out:
# [('romaine lettuce', 'black olives'),
#  ('romaine lettuce', 'grape tomatoes'),
#  ('romaine lettuce', 'garlic'),
#  ('romaine lettuce', 'pepper'),
#  ('romaine lettuce', 'purple onion'),
#  ('black olives', 'grape tomatoes'),
#  ('black olives', 'garlic'),
#  ('black olives', 'pepper'),
#  ('black olives', 'purple onion'),
#  ('grape tomatoes', 'garlic'),
#  ('grape tomatoes', 'pepper'),
#  ('grape tomatoes', 'purple onion'),
#  ('garlic', 'pepper'),
#  ('garlic', 'purple onion'),
#  ('pepper', 'purple onion')]

# %%
# counting

from collections import Counter

cooc_counts = Counter()
ing_counts = Counter()
for ingredients in df['ingredients']:
    for ing in ingredients:
        ing_counts[ing] += 1    # a ingredient counting
    for (ing_x, ing_y) in itertools.combinations(set(ingredients), 2):
        # add only in a consitent order (x, y)
        if ing_x > ing_y:
            ing_x, ing_y = ing_y, ing_x
        cooc_counts[(ing_x, ing_y)] += 1    # co-occurrences counting

# %%
# dataframing

cooc_df = pd.DataFrame(((ing_x, ing_y, ing_counts[ing_x], ing_counts[ing_y], cooc) for (ing_x, ing_y), cooc in cooc_counts.items()), columns = ['ing_x', 'ing_y', 'x_count', 'y_count', 'cooc'])

cooc_df.sample(10)
# Out:
#                     ing_x                       ing_y  x_count  y_count  cooc
# 5995    fresh lemon juice                large shrimp     2105      517    50
# 189677      garlic cloves                        soba     7772       40    10
# 229166        green chile                 swiss chard      384      134     1
# 41847         fresh herbs                        milk       61     2851     5
# 413698       baby spinach  low sodium vegetable stock      330        8     1
# 314306     dark soy sauce                   pork rind      377        8     1
# 421337     egg substitute                   egg yolks       87      681     1
# 77256   green bell pepper              parsley sprigs     1471      176     7
# 339751       lemon pepper            yellow corn meal       43      430     2
# 90953     canned tomatoes              dried rosemary       94      209     5

# %%
# Pick up Example

cooc_df[cooc_df['ing_x'] == 'pork'].sort_values('cooc', ascending = False).head(8)
# Out:
#       ing_x          ing_y  x_count  y_count  cooc
# 566    pork           salt      367    22534   199
# 7225   pork      soy sauce      367     4120   114
# 5144   pork          water      367     9293   107
# 5131   pork          sugar      367     8064    89
# 51115  pork     sesame oil      367     2183    55
# 72121  pork  vegetable oil      367     5516    50
# 29023  pork      scallions      367     2372    43
# 73420  pork         shrimp      367     1145    32

# %%
# Pick up Example

cooc_df[cooc_df['ing_x'] == 'chillies'].sort_values('cooc', ascending = False).head(8)
# Out:
#           ing_x          ing_y  x_count  y_count  cooc
# 3137   chillies           salt      148    22534    67
# 3126   chillies         onions      148    10008    63
# 3125   chillies         garlic      148     9171    59
# 3130   chillies         ginger      148     2190    47
# 58906  chillies   garam masala      148     1179    37
# 19369  chillies  vegetable oil      148     5516    36
# 3124   chillies          water      148     9293    32
# 3133   chillies       tomatoes      148     3812    31

# %% [markdown]
# Most of the highest co-occurrence counts  are usually popular ingredients.
#
# Simple co-occurrences don't get us the imformation that we actually want, the valid co-occurrence

# %% [markdown]
# # Point-wise Mutual Information
#
#
# 공식 : PMI(A,B)=logP(A,B) / (P(A)×P(B))
#
# 이 PMI는 x와 y가 독립적으로 발생했다고 가정했을 때의 x,y의 동시 발생 확률과, 측정된 x와 y의 동시발생 확률을 비교함으로써 두 변수가 얼마만큼의 상관도를 가지는지 판단한다.
#
# P(X) = X occurrence counting / number of all recipes
#
# P(X, Y) = X, Y co-occurrences / sum of all co-occurrences
#
#
# Descriptions : https://www.slideshare.net/RetrieverJo/pmi-twitter-57723391

# %%
cooc_df.head()
# Out:
#                   ing_x      ing_y  x_count  y_count  cooc
# 0        garbanzo beans  seasoning      181      176     1
# 1  feta cheese crumbles  seasoning      476      176     3
# 2                pepper  seasoning     5508      176    25
# 3       romaine lettuce  seasoning      350      176     3
# 4          purple onion  seasoning     2372      176     7

# %%
ing_counts
# Out:
# Counter({'romaine lettuce': 350,
#          'black olives': 283,
#          'grape tomatoes': 276,
#          'garlic': 9171,
#          'pepper': 5508,
#          'purple onion': 2372,
#          'seasoning': 176,
#          'garbanzo beans': 181,
#          'feta cheese crumbles': 476,
#          'plain flour': 206,
#          'ground pepper': 500,
#          'salt': 22534,
#          'tomatoes': 3812,
#          'ground black pepper': 5990,
#          'thyme': 467,
#          'eggs': 4262,
#          'green tomatoes': 125,
#          'yellow corn meal': 430,
#          'milk': 2851,
#          'vegetable oil': 5516,
#          'mayonaise': 983,
#          'cooking oil': 605,
#          'green chilies': 964,
#          'grilled chicken breasts': 6,
#          'garlic powder': 1785,
#          'yellow onion': 1487,
#          'soy sauce': 4120,
#          'butter': 6078,
#          'chicken livers': 78,
#          'water': 9293,
#          'wheat': 35,
#          'black pepper': 3291,
#          'shallots': 1837,
#          'cornflour': 129,
#          'cayenne pepper': 1892,
#          'onions': 10008,
#          'garlic paste': 360,
#          'lemon juice': 1746,
#          'chili powder': 2519,
#          'passata': 30,
#          'oil': 2426,
#          'ground cumin': 3431,
#          'boneless chicken skinless thigh': 445,
#          'garam masala': 1179,
#          'double cream': 57,
#          'natural yogurt': 22,
#          'bay leaf': 1072,
#          'sugar': 8064,
#          'fresh ginger root': 424,
#          'ground cinnamon': 1537,
#          'vanilla extract': 1626,
#          'ground ginger': 850,
#          'powdered sugar': 616,
#          'baking powder': 2168,
#          'olive oil': 9889,
#          'medium shrimp': 558,
#          'chopped cilantro': 988,
#          'jalapeno chilies': 2170,
#          'flat leaf parsley': 1358,
#          'skirt steak': 88,
#          'white vinegar': 687,
#          'sea salt': 1162,
#          'chorizo sausage': 125,
#          'pistachio nuts': 32,
#          'white almond bark': 1,
#          'flour': 1703,
#          'almond extract': 214,
#          'dried cranberries': 63,
#          'fresh pineapple': 71,
#          'pork': 367,
#          'poblano peppers': 147,
#          'corn tortillas': 1224,
#          'cheddar cheese': 556,
#          'iceberg lettuce': 213,
#          'lime': 1820,
#          'chopped cilantro fresh': 2128,
#          'chopped tomatoes': 364,
#          'fresh basil': 1397,
#          'extra-virgin olive oil': 3424,
#          'kosher salt': 3930,
#          'pimentos': 173,
#          'sweet pepper': 75,
#          'dried oregano': 2163,
#          'sharp cheddar cheese': 197,
#          'swiss cheese': 69,
#          'provolone cheese': 196,
#          'canola oil': 1558,
#          'mushrooms': 724,
#          'sausages': 241,
#          'low sodium soy sauce': 533,
#          'fresh ginger': 1846,
#          'dry mustard': 196,
#          'green beans': 425,
#          'white pepper': 544,
#          'sesame oil': 2183,
#          'scallions': 2372,
#          'shaoxing wine': 316,
#          'ground turkey': 202,
#          'crushed red pepper flakes': 646,
#          'corn starch': 2230,
#          'italian parsley leaves': 158,
#          'walnuts': 147,
#          'hot red pepper flakes': 206,
#          'fresh lemon juice': 2105,
#          'trout fillet': 20,
#          'garlic cloves': 7772,
#          'chipotle chile': 204,
#          'fine sea salt': 363,
#          'fresh cilantro': 1052,
#          'ground coriander': 996,
#          'plum tomatoes': 1043,
#          'avocado': 1514,
#          'lime juice': 1329,
#          'flank steak': 319,
#          'fresh parmesan cheese': 345,
#          'all-purpose flour': 5816,
#          'fat free less sodium chicken broth': 588,
#          'chopped fresh chives': 279,
#          'gruyere cheese': 135,
#          'bacon slices': 280,
#          'gnocchi': 48,
#          'fat free milk': 170,
#          'cooking spray': 1854,
#          'tumeric': 933,
#          'vegetable stock': 236,
#          'naan': 48,
#          'red lentils': 134,
#          'red chili peppers': 828,
#          'spinach': 444,
#          'sweet potatoes': 567,
#          'greek yogurt': 296,
#          'lemon curd': 7,
#          'confectioners sugar': 501,
#          'raspberries': 103,
#          'italian seasoning': 483,
#          'broiler-fryer chicken': 9,
#          'zesty italian dressing': 19,
#          'hot chili': 23,
#          'asian fish sauce': 206,
#          'red bell pepper': 2423,
#          'chicken broth': 1949,
#          'yellow squash': 146,
#          'garlic chili sauce': 158,
#          'sliced green onions': 602,
#          'broccolini': 27,
#          'fresh lime juice': 1714,
#          'cooked rice': 505,
#          'chicken breasts': 997,
#          'pork loin': 88,
#          'roasted peanuts': 201,
#          'hoisin sauce': 515,
#          'creamy peanut butter': 137,
#          'chopped fresh mint': 394,
#          'thai basil': 224,
#          'rice': 643,
#          'rice noodles': 332,
#          'beansprouts': 585,
#          'roma tomatoes': 275,
#          'low-fat mayonnaise': 24,
#          'baking potatoes': 249,
#          'spicy brown mustard': 28,
#          'sesame seeds': 859,
#          'red pepper': 576,
#          'yellow peppers': 61,
#          'extra firm tofu': 184,
#          'broccoli': 264,
#          'orange bell pepper': 109,
#          'arrowroot powder': 18,
#          'red curry paste': 157,
#          'marinara sauce': 279,
#          'linguine': 302,
#          'capers': 671,
#          'olives': 212,
#          'lemon zest': 308,
#          'lo mein noodles': 31,
#          'light soy sauce': 431,
#          'dried black mushrooms': 15,
#          'chives': 258,
#          'oyster sauce': 556,
#          'dark soy sauce': 377,
#          'peanuts': 506,
#          'cabbage': 507,
#          'herbs': 106,
#          'fresh tomatoes': 176,
#          'paprika': 1625,
#          'mango': 339,
#          'stock': 120,
#          'chile pepper': 421,
#          'sliced mushrooms': 295,
#          'sherry': 99,
#          'grated parmesan cheese': 2367,
#          'heavy cream': 1466,
#          'spaghetti': 428,
#          'cooked chicken': 377,
#          'green bell pepper': 1471,
#          'egg roll wrappers': 66,
#          'sweet and sour sauce': 17,
#          'molasses': 124,
#          'shredded cabbage': 136,
#          'ground pork': 585,
#          'carrots': 3542,
#          'flour tortillas': 1076,
#          'cheese': 565,
#          'breakfast sausages': 37,
#          'large eggs': 3700,
#          'boiling water': 439,
#          'hot sauce': 850,
#          'potatoes': 1272,
#          'bacon': 780,
#          'fresh parsley': 1988,
#          'andouille sausage': 321,
#          'cajun seasoning': 463,
#          'peanut oil': 760,
#          'celery': 1060,
#          'ground red pepper': 697,
#          'shrimp': 1145,
#          'onion powder': 644,
#          'firm tofu': 256,
#          'turnips': 139,
#          'palm sugar': 164,
#          'sliced chicken': 7,
#          'fish sauce': 1587,
#          'lime wedges': 613,
#          'green papaya': 35,
#          'chile powder': 142,
#          'tamarind paste': 103,
#          'chinese chives': 40,
#          'crushed garlic': 140,
#          'green onions': 3817,
#          'white sugar': 1392,
#          'dried basil': 721,
#          'diced tomatoes': 2065,
#          'johnsonville andouille dinner sausage': 2,
#          'parsley': 436,
#          'jambalaya rice mix': 3,
#          'worcestershire sauce': 851,
#          'hot pepper sauce': 386,
#          'creole seasoning': 342,
#          'bread slices': 61,
#          'great northern beans': 61,
#          'sage leaves': 129,
#          'chinese five-spice powder': 301,
#          'chicken thighs': 413,
#          'star anise': 325,
#          'cream cheese': 710,
#          'shredded cheddar cheese': 948,
#          'black-eyed peas': 244,
#          'tortilla chips': 381,
#          'collard greens': 197,
#          'ham hock': 55,
#          'chicken stock': 1306,
#          'apple cider': 50,
#          'freshly ground pepper': 1183,
#          'bay leaves': 1329,
#          'rib': 70,
#          'light brown sugar': 515,
#          'large garlic cloves': 1096,
#          'oscar mayer deli fresh smoked ham': 3,
#          'hoagie rolls': 22,
#          'salami': 66,
#          'giardiniera': 12,
#          'mozzarella cheese': 577,
#          'pepperoni': 66,
#          'ice cubes': 163,
#          'club soda': 58,
#          'white rum': 22,
#          'turbinado': 64,
#          'enchilada sauce': 381,
#          'picante sauce': 67,
#          'green pepper': 481,
#          'canned black beans': 96,
#          'shredded lettuce': 215,
#          'sour cream': 1959,
#          'salmon fillets': 194,
#          'cumin seed': 1189,
#          'curry powder': 877,
#          'serrano chile': 378,
#          'sauce': 568,
#          'chicken breast halves': 188,
#          'lettuce leaves': 236,
#          'chopped onion': 1561,
#          'mandarin oranges': 38,
#          'orange liqueur': 73,
#          'yellow cake mix': 21,
#          'frosting': 24,
#          'fennel bulb': 261,
#          'lemon olive oil': 1,
#          'grapefruit juice': 19,
#          'white cornmeal': 100,
#          'bacon drippings': 76,
#          'buttermilk': 1077,
#          'crab boil': 20,
#          'old bay seasoning': 129,
#          'crawfish': 144,
#          'sirloin': 34,
#          'mirin': 626,
#          'corn oil': 150,
#          'glass noodles': 54,
#          'sake': 427,
#          'shiitake': 398,
#          'napa cabbage': 270,
#          'whipping cream': 779,
#          'extra sharp cheddar cheese': 63,
#          'quickcooking grits': 111,
#          'monterey jack': 295,
#          'crushed red pepper': 1028,
#          'mussels': 228,
#          'basil': 347,
#          'dry white wine': 1492,
#          'finely chopped onion': 539,
#          'baking soda': 1176,
#          'honey': 1635,
#          'unsalted butter': 3474,
#          'lemon': 1556,
#          'pesto': 150,
#          'white wine': 463,
#          'bread crumbs': 385,
#          'curry': 89,
#          'low sodium beef broth': 28,
#          'pickapeppa sauce': 4,
#          'cold water': 636,
#          'allspice': 156,
#          'fresh thyme': 436,
#          'ground beef': 1057,
#          'melted butter': 341,
#          'matcha green tea powder': 14,
#          'chopped walnuts': 170,
#          'coarse salt': 724,
#          'fenugreek': 48,
#          'urad dal': 81,
#          'white rice': 315,
#          'pizza crust': 55,
#          'part-skim mozzarella cheese': 273,
#          'yukon gold potatoes': 265,
#          'low-fat sour cream': 77,
#          'leeks': 555,
#          '1% low-fat milk': 234,
#          'lemongrass': 449,
#          'unsweetened coconut milk': 239,
#          'peanut sauce': 29,
#          'spareribs': 15,
#          'tamari soy sauce': 114,
#          'golden brown sugar': 104,
#          'dry sherry': 319,
#          'chicken legs': 145,
#          'ghee': 403,
#          'tomato paste': 1438,
#          'ground turmeric': 1201,
#          'cracked black pepper': 505,
#          'minced beef': 38,
#          'dried thyme': 1096,
#          'ginger': 2190,
#          'chillies': 148,
#          'crushed tomatoes': 555,
#          'fresh rosemary': 531,
#          'boneless pork loin': 78,
#          'pappardelle': 13,
#          'coconut milk': 1056,
#          'eggplant': 626,
#          'jasmine rice': 192,
#          'gochujang base': 178,
#          'top round steak': 32,
#          'rice vinegar': 1528,
#          'taiwanese bok choy': 2,
#          'vanilla': 388,
#          'large egg yolks': 723,
#          'orange juice concentrate': 20,
#          'pumpkin purée': 24,
#          'marshmallow creme': 16,
#          'toasted pecans': 34,
#          'maple syrup': 133,
#          'gingersnap': 6,
#          'ground nutmeg': 742,
#          'brown sugar': 1852,
#          'serrano ham': 35,
#          'manchego cheese': 73,
#          'dijon mustard': 642,
#          'sourdough': 14,
#          'membrillo': 1,
#          'burger buns': 8,
#          'panko breadcrumbs': 166,
#          'chickpea flour': 61,
#          'sriracha': 380,
#          'chickpeas': 500,
#          'ground flaxseed': 4,
#          'greens': 122,
#          'tahini': 77,
#          'ground cloves': 459,
#          'whole nutmegs': 18,
#          'ground cardamom': 315,
#          'italian bread': 147,
#          'balsamic vinegar': 696,
#          'sausage casings': 133,
#          'shredded mozzarella cheese': 581,
#          'roasted red peppers': 299,
#          'penne pasta': 216,
#          'saffron': 253,
#          'warm water': 742,
#          'preserved lemon': 76,
#          'harissa': 53,
#          'couscous': 244,
#          'cayenne': 603,
#          'fat skimmed chicken broth': 91,
#          'pitted kalamata olives': 244,
#          'fat': 112,
#          'sweetened condensed milk': 325,
#          'ice': 139,
#          'espresso': 19,
#          'fresh asparagus': 54,
#          'pecans': 176,
#          'crumbled blue cheese': 45,
#          'chuck': 86,
#          'hamburger buns': 67,
#          'okra pods': 30,
#          'watercress': 132,
#          'self rising flour': 240,
#          'softened butter': 58,
#          'food colouring': 44,
#          'madeira': 38,
#          'foie gras': 13,
#          'demi-glace': 5,
#          'sherry vinegar': 199,
#          'white bread': 162,
#          'fuyu persimmons': 6,
#          'egg bread': 5,
#          'fenugreek leaves': 72,
#          'black mustard seeds': 135,
#          'amchur': 108,
#          'coriander': 560,
#          'fingerling potatoes': 26,
#          'ramps': 16,
#          'black peppercorns': 569,
#          'cinnamon sticks': 798,
#          'cardamom pods': 184,
#          'coriander seeds': 498,
#          'asiago': 104,
#          'whole wheat pasta': 18,
#          'sweet onion': 423,
#          'chestnuts': 39,
#          'granulated sugar': 1066,
#          'whole milk ricotta cheese': 67,
#          'coffee ice cream': 10,
#          'mascarpone': 180,
#          'rum': 99,
#          'semisweet chocolate': 209,
#          'chestnut flour': 2,
#          'baby spinach leaves': 124,
#          'chopped garlic': 437,
#          'large shrimp': 517,
#          'barley': 10,
#          'cooked ham': 93,
#          'starchy potatoes': 6,
#          'grated nutmeg': 292,
#          'sirloin tip roast': 6,
#          'steak': 80,
#          'vegetable shortening': 165,
#          'finely chopped fresh parsley': 106,
#          'vinegar': 408,
#          'caul fat': 3,
#          'whole milk': 974,
#          'heavy whipping cream': 266,
#          'kahlúa': 23,
#          'instant espresso powder': 78,
#          'epazote': 51,
#          'radishes': 356,
#          'oregano': 544,
#          'white onion': 898,
#          'hominy': 92,
#          'tomatillos': 402,
#          'pepitas': 31,
#          'catfish fillets': 133,
#          'basmati rice': 399,
#          'cauliflower': 293,
#          'cumin': 1183,
#          'blood orange': 15,
#          'low salt chicken broth': 481,
#          'white wine vinegar': 440,
#          'tomato sauce': 1073,
#          'shredded carrots': 194,
#          'english muffins, split and toasted': 4,
#          'vegetable oil cooking spray': 330,
#          'chopped green bell pepper': 326,
#          'prawns': 112,
#          'rice flour': 176,
#          'seasoning salt': 174,
#          'lasagna noodles': 249,
#          'ranch dressing': 92,
#          'evaporated milk': 256,
#          'minced garlic': 2001,
#          'red wine vinegar': 924,
#          'boneless chop pork': 44,
#          'chile paste': 58,
#          'lower sodium soy sauce': 73,
#          'dark sesame oil': 272,
#          'raisins': 595,
#          'pearl barley': 40,
#          'slivered almonds': 213,
#          'chocolate bars': 11,
#          'marshmallows': 8,
#          'cinnamon graham crackers': 1,
#          'chopped celery': 533,
#          'mustard powder': 63,
#          'cod': 43,
#          'minced onion': 231,
#          'dry bread crumbs': 371,
#          'golden raisins': 291,
#          'margarine': 288,
#          'mace': 106,
#          'brewed tea': 3,
#          'candied orange peel': 32,
#          'grated lemon zest': 437,
#          'dried currants': 106,
#          'rum extract': 4,
#          'dark brown sugar': 395,
#          'noodles': 274,
#          'baby bok choy': 102,
#          'black bean sauce': 39,
#          'red potato': 247,
#          'chinese rice wine': 169,
#          'black beans': 1143,
#          'quinoa': 146,
#          'frozen corn': 209,
#          'vegetable broth': 506,
#          'yellow bell pepper': 347,
#          'orange': 439,
#          'duck': 61,
#          'dried mint flakes': 41,
#          'penne rigate': 20,
#          'feta cheese': 339,
#          'ras el hanout': 53,
#          'ground lamb': 165,
#          'large egg whites': 624,
#          '2% reduced-fat milk': 85,
#          'napa cabbage leaves': 21,
#          'chicken leg quarters': 28,
#          'cucumber': 970,
#          'long-grain rice': 446,
#          'crusty bread': 51,
#          'baby potatoes': 22,
#          'smoked streaky bacon': 6,
#          'piloncillo': 24,
#          'ground allspice': 443,
#          'hibiscus': 3,
#          'fresh oregano': 469,
#          'chocolate morsels': 26,
#          'cream sweeten whip': 53,
#          'instant espresso granules': 9,
#          'chocolate covered coffee beans': 3,
#          'unflavored gelatin': 130,
#          'pound cake': 17,
#          'pinenuts': 435,
#          'zucchini': 1109,
#          'baby carrots': 90,
#          'fresh basil leaves': 615,
#          'asparagus spears': 74,
#          'frozen peas': 476,
#          'arborio rice': 361,
#          'yellow crookneck squash': 12,
#          'chipotles in adobo': 243,
#          'instant white rice': 10,
#          'cilantro leaves': 1438,
#          'red beans': 91,
#          'skinless chicken thighs': 11,
#          'lime zest': 168,
#          'condensed cream of mushroom soup': 67,
#          'condensed cream of chicken soup': 74,
#          'lean ground beef': 482,
#          'mexican cheese blend': 220,
#          'chunky salsa': 84,
#          'taco seasoning mix': 222,
#          'chorizo spanish': 1,
#          'pineapple juice': 107,
#          'dark rum': 133,
#          'daikon': 190,
#          'pork ribs': 39,
#          'goji berries': 12,
#          'oysters': 79,
#          'salsa': 1221,
#          'demerara sugar': 11,
#          'egg whites': 555,
#          'fruit': 62,
#          'frozen pastry puff sheets': 130,
#          'mixed spice': 42,
#          'parsnips': 87,
#          'chili oil': 140,
#          'brown mustard seeds': 78,
#          'unsalted cashews': 32,
#          'thai green curry paste': 61,
#          'kecap manis': 23,
#          'frozen broad beans': 3,
#          'basil leaves': 335,
#          'chili flakes': 200,
#          'chicken tenderloin': 24,
#          'creole style seasoning': 11,
#          'condensed cheddar cheese soup': 6,
#          'refried beans': 306,
#          'grated jack cheese': 73,
#          'egg yolks': 681,
#          'asparagus': 278,
#          'fresh leav spinach': 66,
#          'cheese tortellini': 65,
#          'cherry tomatoes': 560,
#          'navy beans': 29,
#          'nonfat milk': 21,
#          'granny smith apples': 146,
#          'lard': 198,
#          'pecorino romano cheese': 197,
#          'fresh fava bean': 20,
#          'italian sausage': 164,
#          'pasta sheets': 11,
#          'spinach leaves': 88,
#          'low-fat natural yogurt': 8,
#          'flora cuisine': 16,
#          'curry paste': 132,
#          'bone-in chicken breasts': 22,
#          'white hominy': 77,
#          'dried chile peppers': 6,
#          'frozen whipped topping': 19,
#          'chocolate instant pudding': 11,
#          'instant butterscotch pudding mix': 1,
#          'graham cracker crumbs': 40,
#          'fennel seeds': 437,
#          'kalamata': 263,
#          'kielbasa': 33,
#          'celery ribs': 722,
#          'ham': 280,
#          'moong dal': 38,
#          'capsicum': 63,
#          'green mango': 10,
#          'toasted sesame oil': 441,
#          'tofu': 175,
#          'short-grain rice': 81,
#          'dried shiitake mushrooms': 153,
#          'gari': 57,
#          'turkish bay leaves': 22,
#          'dried chickpeas': 26,
#          'semolina': 82,
#          'vine ripened tomatoes': 49,
#          'bittersweet chocolate': 176,
#          'fat free yogurt': 83,
#          'skim milk': 105,
#          'angel food cake': 7,
#          'unsweetened cocoa powder': 319,
#          'instant espresso': 13,
#          'organic chicken': 10,
#          'anise': 75,
#          'zinfandel': 11,
#          'orange blossom honey': 13,
#          'calimyrna figs': 18,
#          'clove': 768,
#          'plain whole-milk yogurt': 61,
#          'reduced sodium soy sauce': 190,
#          'beef stock': 208,
#          'chuck roast': 80,
#          'corn flakes cereal': 7,
#          'coleslaw': 27,
#          'garlic salt': 302,
#          'chili paste': 160,
#          'red pepper flakes': 830,
#          'kiwi': 31,
#          'asian pear': 53,
#          'chees fresco queso': 47,
#          'swiss chard': 134,
#          'veal cutlets': 28,
#          'pasta': 400,
#          'wakame': 21,
#          'extra-lean ground beef': 14,
#          'scallion greens': 71,
#          'wonton wrappers': 191,
#          'peeled fresh ginger': 730,
#          'nonstick spray': 60,
#          'chopped fresh thyme': 452,
#          'chicken bones': 12,
#          'green bell pepper, slice': 75,
#          'anchovy fillets': 241,
#          'crusty rolls': 6,
#          'coconut oil': 263,
#          'almond flour': 49,
#          'coconut aminos': 23,
#          'green peas': 272,
#          'clams': 119,
#          'boneless skinless chicken breast halves': 766,
#          'seasoned rice wine vinegar': 70,
#          'snow peas': 217,
#          'hard-boiled egg': 132,
#          'artichoke hearts': 172,
#          'stuffing': 21,
#          'coriander powder': 302,
#          'maida flour': 20,
#          'pita bread rounds': 26,
#          'grated gruyère cheese': 77,
#          'udon': 68,
#          'red miso': 36,
#          'silken tofu': 56,
#          'button mushrooms': 191,
#          'whole peeled tomatoes': 155,
#          'shredded monterey jack cheese': 398,
#          'pickled jalapenos': 35,
#          'broccoli rabe': 66,
#          'parmigiano reggiano cheese': 436,
#          'fontina': 38,
#          'thai chile': 276,
#          'peppercorns': 181,
#          'refrigerated piecrusts': 87,
#          'cream of chicken soup': 109,
#          'frozen peas and carrots': 23,
#          'low sodium chicken broth': 426,
#          'pasta sauce': 330,
#          'olive oil flavored cooking spray': 56,
#          'frozen chopped spinach': 269,
#          'part-skim ricotta cheese': 152,
#          'manicotti shells': 24,
#          'fettucine': 189,
#          'parmesan cheese': 717,
#          'chicken bouillon': 89,
#          'chili paste with garlic': 12,
#          'fresh veget': 6,
#          'taco sauce': 80,
#          'guacamole': 232,
#          'salsa verde': 165,
#          'condiments': 14,
#          'pork shoulder roast': 34,
#          'tortillas': 289,
#          'rose petals': 6,
#          'almonds': 241,
#          'pistachios': 85,
#          'chicken wings': 165,
#          'drumstick': 8,
#          'green chile': 384,
#          'peeled tomatoes': 87,
#          'chicken': 1237,
#          'chiles': 408,
#          'adobo sauce': 116,
#          'ancho powder': 101,
#          'chipotle chile powder': 57,
#          'old el paso flour tortillas': 8,
#          'cranberry sauce': 5,
#          'beer': 258,
#          'chili sauce': 177,
#          'beef rib short': 92,
#          'miso paste': 92,
#          'seaweed': 72,
#          'dashi': 155,
#          'fresh dill': 303,
#          'yoghurt': 304,
#          'myzithra': 2,
#          'phyllo': 22,
#          'kefalotyri': 9,
#          'okra': 335,
#          'cracker crumbs': 14,
#          'philadelphia cream cheese': 25,
#          'crab meat': 35,
#          'savoy cabbage': 67,
#          'boneless chicken thighs': 71,
#          'potato starch': 77,
#          'cream of tartar': 203,
#          'semi-sweet chocolate morsels': 94,
#          'cake flour': 206,
#          'ricotta cheese': 441,
#          'serrano': 38,
#          'steel-cut oats': 8,
#          'hazelnuts': 128,
#          'hazelnut oil': 9,
#          'sweet cherries': 23,
#          'fire roasted diced tomatoes': 21,
#          'red kidnei beans, rins and drain': 26,
#          'wasabi paste': 47,
#          'black sesame seeds': 61,
#          'japanese soy sauce': 34,
#          'fresh salmon': 5,
#          'dried porcini mushrooms': 125,
#          'dry red wine': 376,
#          'hot water': 441,
#          'fat free less sodium beef broth': 23,
#          'cremini mushrooms': 166,
#          'creole mustard': 86,
#          'prepared horseradish': 91,
#          'celery salt': 60,
#          'shrimp and crab boil seasoning': 12,
#          'turnip greens': 39,
#          'butternut squash': 220,
#          'apples': 211,
#          'country ham': 64,
#          'frozen edamame beans': 22,
#          'whole kernel corn, drain': 133,
#          'strong white bread flour': 18,
#          'salted butter': 97,
#          'sunflower oil': 123,
#          'kalonji': 6,
#          'instant yeast': 89,
#          'fresh coriander': 358,
#          'cooked white rice': 176,
#          'mixed mushrooms': 11,
#          'wood ear mushrooms': 35,
#          'vegetables': 246,
#          'taco seasoning': 335,
#          'bell pepper': 500,
#          'boneless skinless chicken breasts': 1377,
#          'shredded cheese': 195,
#          'eau de vie': 4,
#          'leaves': 109,
#          'cane sugar': 27,
#          'baking apples': 5,
#          'salt and ground black pepper': 270,
#          'sliced black olives': 187,
#          'chopped green chilies': 78,
#          'rosemary leaves': 23,
#          'lean steak': 4,
#          'guinness lager': 1,
#          'dried rosemary': 209,
#          'water chestnuts, drained and chopped': 10,
#          'chinese cabbage': 73,
#          'dipping sauces': 79,
#          'lean ground pork': 53,
#          'pico de gallo': 107,
#          'cheese slices': 26,
#          'chorizo': 89,
#          'french bread': 228,
#          'dried dillweed': 40,
#          'red wine': 292,
#          'lamb': 78,
#          'plain yogurt': 456,
#          'kale': 186,
#          'mexican beer': 33,
#          'boneless beef short ribs': 9,
#          'guajillo': 14,
#          'saffron threads': 353,
#          'fresh spinach': 283,
#          'banana squash': 3,
#          'cannellini beans': 252,
#          'shortening': 276,
#          'franks hot sauce': 1,
#          'pears': 123,
#          'light pancake syrup': 10,
#          'puff pastry': 62,
#          'apple cider vinegar': 347,
#          'mushroom powder': 3,
#          'bone in chicken thighs': 47,
#          'fresh bay leaves': 29,
#          'cilantro': 1423,
#          'skinless chicken breasts': 74,
#          'light sour cream': 79,
#          'fava beans': 33,
#          'fresh tarragon': 172,
#          'kidney beans': 189,
#          'orzo pasta': 43,
#          'dri leav thyme': 43,
#          'wasabi': 34,
#          'jumbo shrimp': 80,
#          'sticky rice': 37,
#          'white sesame seeds': 86,
#          'chopped almonds': 54,
#          'baby arugula': 57,
#          'tequila': 168,
#          'margarita mix': 6,
#          'crust': 32,
#          'grits': 235,
#          'pecan halves': 126,
#          'corn syrup': 81,
#          'superfine sugar': 92,
#          'blackberries': 112,
#          'whiskey': 39,
#          'luke warm water': 9,
#          'active dry yeast': 486,
#          'fresh mint': 551,
#          'jamaican jerk season': 26,
#          'pineapple preserves': 6,
#          'chicken drumsticks': 127,
#          'pitas': 59,
#          'goat cheese': 209,
#          'gingerroot': 143,
#          'rib eye steaks': 55,
#          'hot bean paste': 14,
#          'medjool date': 24,
#          'diced bell pepper': 10,
#          'cream': 324,
#          'smoked paprika': 431,
#          'reduced fat milk': 99,
#          'smoked trout': 4,
#          'garlic puree': 20,
#          'green cardamom pods': 92,
#          'tomato purée': 258,
#          'pickled jalapeno peppers': 9,
#          'romaine lettuce leaves': 54,
#          'crema mexicana': 25,
#          'chile sauce': 44,
#          'queso fresco': 182,
#          'boston lettuce': 35,
#          'persian cucumber': 26,
#          'peanut butter': 172,
#          'rice paper': 93,
#          'korean chile flakes': 24,
#          'red chile powder': 25,
#          'boneless chicken breast': 188,
#          'cashew nuts': 290,
#          'kashmiri chile': 2,
#          'kasuri methi': 67,
#          'mustard oil': 37,
#          'ginger paste': 154,
#          'cinnamon': 878,
#          'tomato ketchup': 83,
#          'pecan pie': 1,
#          'tostada shells': 29,
#          'grouper': 20,
#          'corn kernels': 348,
#          'ricotta salata': 35,
#          'pecorino cheese': 69,
#          'grana padano': 10,
#          'kaffir lime leaves': 168,
#          'corn': 418,
#          'soba noodles': 83,
#          'galangal': 104,
#          'green curry paste': 59,
#          'bamboo shoots': 173,
#          'chopped nuts': 17,
#          'bourbon whiskey': 262,
#          'ketchup': 557,
#          'rhubarb': 31,
#          'liquid': 69,
#          'store bought low sodium chicken stock': 37,
#          'safflower oil': 44,
#          'jeera': 31,
#          'cardamom': 140,
#          'crema': 47,
#          'salmon steaks': 16,
#          'jam': 35,
#          'karashi': 2,
#          'spring onions': 509,
#          'free range egg': 25,
#          'jicama': 110,
#          'water chestnuts': 229,
#          'diced celery': 109,
#          'shredded sharp cheddar cheese': 204,
#          'dinner rolls': 11,
#          'cactus pad': 3,
#          'fenugreek seeds': 102,
#          'cauliflower flowerets': 3,
#          'boiling potatoes': 124,
#          'baby spinach': 330,
#          'tuna steaks': 52,
#          'spices': 211,
#          'octopuses': 17,
#          'vidalia onion': 133,
#          'smoked gouda': 33,
#          'small red potato': 96,
#          'tuna': 60,
#          'fat-free refried beans': 13,
#          'low-fat milk': 56,
#          'fresh lime': 35,
#          'ground white pepper': 428,
#          'bertolli® classico olive oil': 22,
#          'bacon, crisp-cooked and crumbled': 5,
#          'bertolli vineyard premium collect marinara with burgundi wine sauc': 6,
#          'bread crumb fresh': 205,
#          'margarita salt': 3,
#          '(    oz.) tomato sauce': 15,
#          'ground veal': 52,
#          'italian seasoning mix': 4,
#          'beef': 334,
#          'solid pack pumpkin': 16,
#          'fresh thyme leaves': 232,
#          'whole grain thin spaghetti': 1,
#          'grapeseed oil': 94,
#          'organic sugar': 7,
#          'dried cherry': 24,
#          'straw mushrooms': 39,
#          'vidalia': 6,
#          'haricots verts': 59,
#          'wax beans': 7,
#          'prosciutto': 352,
#          'romano cheese': 138,
#          'cooked shrimp': 119,
#          'crabmeat': 103,
#          'strawberries': 261,
#          'green peppercorns': 26,
#          'pork loin chops': 60,
#          'chipotle peppers': 86,
#          'blueberri preserv': 1,
#          'filet': 41,
#          'thyme leaves': 52,
#          'coffee beans': 23,
#          'vegan margarine': 6,
#          'pork shoulder': 175,
#          'parsley leaves': 72,
#          'fresh raspberries': 107,
#          'frozen whole kernel corn': 110,
#          'wish bone guacamol ranch dress': 1,
#          'torn romain lettuc leav': 3,
#          'russet potatoes': 326,
#          'mexican chorizo': 41,
#          'colby cheese': 27,
#          'half & half': 423,
#          'dry vermouth': 55,
#          'canned low sodium chicken broth': 121,
#          'roasted salted cashews': 3,
#          'fresh lemon': 31,
#          'toasted sesame seeds': 370,
#          'paneer cheese': 14,
#          'lemon grass': 134,
#          'thai fish sauce': 136,
#          ...})

# %%
sum(ing_counts.values())
# Out:
# 535670

# %%
len(ing_counts.values())
# Out:
# 7126

# %%
# origin - y : len으로 나눔

px = cooc_df['x_count'] / sum(ing_counts.values())
py = cooc_df['y_count'] / (len(ing_counts.values()))    # 여기가 왜 len일까 내가 붙여넣음.. 그래야 되는 거 아닌가?

pxy = cooc_df['cooc'] / cooc_df['cooc'].sum()

cooc_df['PMI'] = np.log(pxy / (px * py))

cooc_df.head()
# Out:
#                   ing_x      ing_y  x_count  y_count  cooc       PMI
# 0        garbanzo beans  seasoning      181      176     1 -3.255466
# 1  feta cheese crumbles  seasoning      476      176     3 -3.123774
# 2                pepper  seasoning     5508      176    25 -3.452050
# 3       romaine lettuce  seasoning      350      176     3 -2.816290
# 4          purple onion  seasoning     2372      176     7 -3.882547

# %%
cooc_df.sort_values('PMI', ascending = False).head(10)
# Out:
#                                               ing_x  \
# 473897                            chocolate extract
# 275199                   ragu classic alfredo sauce
# 171257  johnsonville andouille fully cooked sausage
# 435670                                    snow crab
# 252710                                dried oysters
# 163025                             conimex wok olie
# 208234                                brownie layer
# 484430                       cooked cut green beans
# 200525                               dumpling dough
# 460860                                bermuda onion
#
#                                                     ing_y  x_count  y_count  \
# 473897                          chocolate graham crackers        1        1
# 275199                ragu golden veggie fettuccine pasta        1        1
# 171257                      klondike rose red skin potato        1        1
# 435670                                        spot prawns        1        1
# 252710                                     wood mushrooms        1        1
# 163025  conimex woksaus specials vietnamese gember kno...        1        1
# 208234                            chocolate ice cream mix        1        1
# 484430                   wish-bone deluxe french dressing        1        1
# 200525                                        red vinegar        1        1
# 460860                                    snip fresh dill        1        1
#
#         cooc       PMI
# 473897     1  7.113515
# 275199     1  7.113515
# 171257     1  7.113515
# 435670     1  7.113515
# 252710     1  7.113515
# 163025     1  7.113515
# 208234     1  7.113515
# 484430     1  7.113515
# 200525     1  7.113515
# 460860     1  7.113515

# %% [markdown]
# need min_count
